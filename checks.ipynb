# %%
import pandas as pd
from pathlib import Path

data_file=Path("aqar_fm_listings.csv")
df= pd.read_csv(data_file)
# find all rows with missing values in these columns ['title', 'url', 'price', 'description', 'city', 'neighborhood', 'sale_type']
missing_df = df[df[['title', 'url', 'price', 'description', 'city', 'neighborhood', 'sale_type']].isnull().any(axis=1)]
missing_df[['title', 'url', 'price', 'description', 'city', 'neighborhood', 'sale_type']]
# Out:
#                                                   title  \
# 31    مكتب تجاري للإيجار في شارع الصحابة, حي المونسي...
# 49    شقة للبيع في شارع سيف الدين بن ابي النصر الخطي...
# 87    شقة للإيجار في شارع المغيرة بن الحارث, حي حي ا...
# 173   فيلا للبيع في شارع ممر12, حي الفاروق, مدينة ال...
# 181   فيلا للبيع في شارع الحفناوي, حي العارض, مدينة ...
# ...                                                 ...
# 6096  أرض للبيع في شارع بني عمرو 845, حي الفرعه, مدي...
# 6101  شقة للإيجار في شارع 18180594, حي المرسلات, مدي...
# 6115  دور للإيجار في شارع محمد الطيب بن صالح التونسي...
# 6133  دور للبيع في شارع 1077880, حي الريف, مدينة الم...
# 6136  عمارة للبيع في شارع مقاتل بن سليمان, حي القيرو...
#
#                                                     url              price  \
# 31    https://sa.aqar.fm/%D9%85%D9%83%D8%AA%D8%A8-%D...            377,000
# 49    https://sa.aqar.fm/%D8%B4%D9%82%D9%82-%D9%84%D...  569,500  خصم  2 %
# ...
