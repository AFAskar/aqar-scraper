# %%
import pandas as pd
from pathlib import Path

data_file=Path("aqar_fm_listings.csv")
df= pd.read_csv(data_file)
# unique values in 'sale_type' column
unique_sale_types = df['sale_type'].unique()
print("Unique sale types in the dataset:", unique_sale_types)
# Out:
# Unique sale types in the dataset: ['sale' 'auction']
