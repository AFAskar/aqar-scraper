# %%
import pandas as pd
from pathlib import Path

data_file=Path("aqar_fm_listings.csv")
df= pd.read_csv(data_file)
# find all rows where 'spanvalue' contains the word 'ايجار' or 'شهري' or 'سنوي'
df= df[df["spanvalue"].str.contains("ايجار|شهري|سنوي", na=False)]
df
# Out:
#                                                   title  \
# 5     شقة للإيجار في شارع رقم 272, حي الياسمين, مدين...
# 8     شقة للإيجار في شارع وادي الجوف, حي الصحافة, مد...
# 9     فيلا للإيجار في شارع شداد بن اوس, حي المرجان, ...
# 13    شقة للإيجار في شارع الكوثر, حي العارض, مدينة ا...
# 14    شقة للإيجار في شارع الثاميه, حي الملقا, مدينة ...
# ...                                                 ...
# 6230  شقة للإيجار في شارع ظهره العودة غرب 96, حي ظهر...
# 6233  شقة للإيجار في شارع سعيد بن نفيل, حي الرمال, م...
# 6239  شقة للإيجار في شارع المشورة, حي العقربية, مدين...
# 6240  شقة للإيجار في شارع عباس مالكي, حي الجسر, مدين...
# 6245  استراحة للإيجار في شارع علي بن ابي طالب, حي ال...
#
#                                                     url    price  \
# 5     https://sa.aqar.fm/%D8%B4%D9%82%D9%82-%D9%84%D...   55,000
# 8     https://sa.aqar.fm/%D8%B4%D9%82%D9%82-%D9%84%D...   58,200
# 9     https://sa.aqar.fm/%D9%81%D9%84%D9%84-%D9%84%D...  135,000
# ...
